# %%
import pandas as pd

posicoes_bronze = pd.read_csv("posicoes_onibus_11-42-00_bronze.csv")

# %%
posicoes_bronze
# Out:
#       hora_requisicao  codigo_linha nome_linha  \
# 0            11:42:00          1369    978A-10
# 1            11:42:00          1369    978A-10
# 2            11:42:00          1369    978A-10
# 3            11:42:00          1369    978A-10
# 4            11:42:00          1369    978A-10
# ...               ...           ...        ...
# 10219        11:42:00         35222    3015-10
# 10220        11:42:00         35275     8300-1
# 10221        11:42:00         35216    4093-10
# 10222        11:42:00         33824    3768-10
# 10223        11:42:00         35257    TREI-10
#
#                                       letreiro  codigo_onibus          x  \
# 0       METRÔ BARRA FUNDA - TERM. CACHOEIRINHA          12475 -46.681714
# 1       METRÔ BARRA FUNDA - TERM. CACHOEIRINHA          12594 -46.667098
# 2       METRÔ BARRA FUNDA - TERM. CACHOEIRINHA          12429 -46.670049
# 3       METRÔ BARRA FUNDA - TERM. CACHOEIRINHA          12467 -46.688586
# ...
