# %%
import pandas as pd
from utils.load_csv import load_csv

# %%
df_posicoes = load_csv('df_posicoes.csv')

df_posicoes
# Out:
#           linha  id_onibus             timestamp        lat        lon  \
# 0       342M-10      41610  2025-09-03T11:27:39Z -23.519454 -46.546797
# 1       342M-10      41501  2025-09-03T11:27:27Z -23.599379 -46.485247
# 2       342M-10      41783  2025-09-03T11:27:57Z -23.564488 -46.513625
# 3       342M-10      41510  2025-09-03T11:27:27Z -23.613857 -46.476304
# 4       342M-10      41583  2025-09-03T11:27:38Z -23.613857 -46.476304
# ...         ...        ...                   ...        ...        ...
# 147587  8009-10      10423  2025-09-03T11:34:57Z -23.463490 -46.746013
# 147588  6L02-10      66258  2025-09-03T11:34:51Z -23.910759 -46.766351
# 147589  8021-10      80113  2025-09-03T11:35:01Z -23.577175 -46.765109
# 147590  6815-10      72011  2025-09-03T11:34:35Z -23.656454 -46.763021
# 147591  3903-10      32842  2025-09-03T11:32:07Z -23.524180 -46.549048
#
#         is_eletrico            modelo
# 0             False  Articulado (23m)
# ...

# %%
df_posicoes['id_2'] = df_posicoes['linha'] + '_' + df_posicoes['id_onibus'].astype(str)

df_posicoes
# Out:
#           linha  id_onibus             timestamp        lat        lon  \
# 0       342M-10      41610  2025-09-03T11:27:39Z -23.519454 -46.546797
# 1       342M-10      41501  2025-09-03T11:27:27Z -23.599379 -46.485247
# 2       342M-10      41783  2025-09-03T11:27:57Z -23.564488 -46.513625
# 3       342M-10      41510  2025-09-03T11:27:27Z -23.613857 -46.476304
# 4       342M-10      41583  2025-09-03T11:27:38Z -23.613857 -46.476304
# ...         ...        ...                   ...        ...        ...
# 147587  8009-10      10423  2025-09-03T11:34:57Z -23.463490 -46.746013
# 147588  6L02-10      66258  2025-09-03T11:34:51Z -23.910759 -46.766351
# 147589  8021-10      80113  2025-09-03T11:35:01Z -23.577175 -46.765109
# 147590  6815-10      72011  2025-09-03T11:34:35Z -23.656454 -46.763021
# 147591  3903-10      32842  2025-09-03T11:32:07Z -23.524180 -46.549048
#
#         is_eletrico            modelo           id_2
# 0             False  Articulado (23m)  342M-10_41610
# ...

# %%
df_posicoes['id_onibus'].nunique()
# Out:
# 11524

# %%
df_posicoes['id_2'].nunique()
# Out:
# 11544

# %%
df_final = load_csv('df_final.csv')

df_final
# Out:
#         id_onibus  distancia_percorrida                ponto_inicial  \
# 0           41610              0.001100    [-46.546797, -23.5194545]
# 1           41610              0.000000  [-46.547896, -23.519413375]
# 2           41610              0.003288  [-46.547896, -23.519413375]
# 3           41610              0.001866   [-46.550168, -23.52178975]
# 4           41610              0.001959    [-46.5514535, -23.523143]
# ...           ...                   ...                          ...
# 136063      76393              0.000000       [-46.727531, -23.6458]
# 136064      77879              0.000000   [-46.7642095, -23.6572335]
# 136065      31643              0.000746    [-46.625438, -23.5531905]
# 136066      48809              0.001489      [-46.449493, -23.62271]
# 136067      31518              0.000000    [-46.481164, -23.5174155]
#
#                                               ponto_final  \
# 0       [np.float64(-46.547896), np.float64(-23.519413...
# ...

# %%
df_final['id_onibus'].nunique()
# Out:
# 11504

# %%
df_final['momento_final'].describe()
# Out:
# count                        136068
# unique                          553
# top       2025-09-03 11:30:56+00:00
# freq                            596
# Name: momento_final, dtype: object

# %%
df_final['momento_inicial'] = pd.to_datetime(df_final['momento_inicial'])
df_final['momento_final']   = pd.to_datetime(df_final['momento_final'])

# %%
df_final['duracao'] = (df_final['momento_final'] - df_final['momento_inicial']).dt.total_seconds()

df_final
# Out:
#         id_onibus  distancia_percorrida                ponto_inicial  \
# 0           41610              0.001100    [-46.546797, -23.5194545]
# 1           41610              0.000000  [-46.547896, -23.519413375]
# 2           41610              0.003288  [-46.547896, -23.519413375]
# 3           41610              0.001866   [-46.550168, -23.52178975]
# 4           41610              0.001959    [-46.5514535, -23.523143]
# ...           ...                   ...                          ...
# 136063      76393              0.000000       [-46.727531, -23.6458]
# 136064      77879              0.000000   [-46.7642095, -23.6572335]
# 136065      31643              0.000746    [-46.625438, -23.5531905]
# 136066      48809              0.001489      [-46.449493, -23.62271]
# 136067      31518              0.000000    [-46.481164, -23.5174155]
#
#                                               ponto_final  \
# 0       [np.float64(-46.547896), np.float64(-23.519413...
# ...

# %%
df_final['velocidade'] = df_final['distancia_percorrida'] / df_final['duracao']

df_final
# Out:
#         id_onibus  distancia_percorrida                ponto_inicial  \
# 0           41610              0.001100    [-46.546797, -23.5194545]
# 1           41610              0.000000  [-46.547896, -23.519413375]
# 2           41610              0.003288  [-46.547896, -23.519413375]
# 3           41610              0.001866   [-46.550168, -23.52178975]
# 4           41610              0.001959    [-46.5514535, -23.523143]
# ...           ...                   ...                          ...
# 136063      76393              0.000000       [-46.727531, -23.6458]
# 136064      77879              0.000000   [-46.7642095, -23.6572335]
# 136065      31643              0.000746    [-46.625438, -23.5531905]
# 136066      48809              0.001489      [-46.449493, -23.62271]
# 136067      31518              0.000000    [-46.481164, -23.5174155]
#
#                                               ponto_final  \
# 0       [np.float64(-46.547896), np.float64(-23.519413...
# ...

# %%
df_final[df_final['id_onibus'] == 80148]
# Out:
#         id_onibus  distancia_percorrida                         ponto_inicial  \
# 130963      80148              0.000000            [-46.7137425, -23.5696525]
# 130964      80148              0.000442            [-46.7137425, -23.5696525]
# 130965      80148              0.000847   [-46.713321750000006, -23.56978875]
# 130966      80148              0.001118     [-46.71251600000001, -23.5700495]
# 130967      80148              0.000335          [-46.7114505, -23.570387875]
# 130968      80148              0.001284          [-46.7111315, -23.570489625]
# 130969      80148              0.000000           [-46.709908375, -23.570879]
# 130970      80148              0.000000           [-46.709908375, -23.570879]
# 130971      80148              0.001698           [-46.709908375, -23.570879]
# 130972      80148              0.000657  [-46.708289875000006, -23.571393625]
# 130973      80148              0.001711            [-46.7076625, -23.5715885]
# ...
